# %% [markdown]
# <a href="https://colab.research.google.com/github/rajlaxmiac/LogicMojo-AI-ML-April26-RajlaxmiSingh/blob/main/Copy_of_phython1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# my list with duplicates
my_list = [8, 9, 2, 2, 3, 4, 5, 2]

new_list = []


for x in my_list:
    if x not in new_list:
        new_list.append(x)


print(new_list)
# Out:
# [8, 9, 2, 3, 4, 5]
